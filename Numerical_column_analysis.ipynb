# %% [markdown]
# ### Numerical column analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ds = pd.read_csv(r'C:\Users\ankush\Downloads\Visadataset.csv')
ds
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat = ds.select_dtypes(include = 'object').columns
num = ds.select_dtypes(exclude = 'object').columns

# %%
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# ### Prevailing_wage column

# %%
pwage = ds['prevailing_wage']

# %%
ds['prevailing_wage'].value_counts()
# Out:
# prevailing_wage
# 109.06       2
# 118.43       2
# 60948.15     2
# 110.51       2
# 88664.77     2
#             ..
# 156326.33    1
# 43630.58     1
# 54614.42     1
# 28989.87     1
# 70813.09     1
# Name: count, Length: 25454, dtype: int64

# %%
min(ds['prevailing_wage'])
# Out:
# 2.1367

# %%
print(np.min(pwage))
# Out:
# 2.1367

# %%
print(np.max(pwage))
# Out:
# 319210.27

# %%
max(pwage)
# Out:
# 319210.27

# %%
ds['prevailing_wage'].shape
# Out:
# (25480,)

# %%
len(ds['prevailing_wage'])
# Out:
# 25480

# %%
print(pwage.mean())
# Out:
# 74455.81459209183

# %%
print(np.median(pwage))
# Out:
# 70308.20999999999

# %%
print(pwage.mode())
# Out:
# 0        100.66
# 1        102.70
# 2        105.96
# 3        108.12
# 4        109.06
# 5        110.51
# 6        111.11
# 7        113.60
# 8        118.43
# 9        122.65
# 10       127.89
# 11       134.15
# 12       138.76
# 13      6036.67
# 14     21894.51
# 15     24258.73
# 16     58770.05
# 17     60948.15
# 18     64357.58
# 19     74645.92
# 20     82560.28
# 21     87751.88
# 22     88664.77
# 23     93356.03
# 24    126813.75
# 25    149907.39
# Name: prevailing_wage, dtype: float64

# %% [markdown]
# ### Percentile-quentile

# %%
# 25 percentile - value

# %%
print(np.percentile(pwage,25))
# Out:
# 34015.479999999996

# %%
print(np.quantile(pwage,0.25))
# Out:
# 34015.479999999996

# %%
print(np.percentile(pwage,50))
# Out:
# 70308.20999999999

# %%
print(np.quantile(pwage,0.50))
# Out:
# 70308.20999999999

# %%
print(np.percentile(pwage,75))
# Out:
# 107735.51250000001

# %%
print(np.quantile(pwage,0.75))
# Out:
# 107735.51250000001

# %%
v_ds = pwage.count()
v_ds1 = np.min(pwage)
v_ds2 = np.percentile(pwage,25)
v_ds3 = np.mean(pwage)
v_ds4 = np.median(pwage)
v_ds5 = np.percentile(pwage,50)
v_ds6 = np.percentile(pwage,75)
v_ds7 = np.max(pwage)

# %%
matrics=[v_ds,v_ds1,v_ds2,v_ds3,v_ds4,v_ds5,v_ds6,v_ds7]
pd.DataFrame(matrics)
ID = ['count','min','p_25','mean','median','p_50','p_75','max']
pd.DataFrame(matrics,index = ID,columns = ['Prevailing_wage'])
# Out:
#         Prevailing_wage
# count      25480.000000
# min            2.136700
# p_25       34015.480000
# mean       74455.814592
# median     70308.210000
# p_50       70308.210000
# p_75      107735.512500
# max       319210.270000

# %%
v_ddf = []
for i in num:
    pwage = ds[i]
    v_ds = pwage.count()
    v_ds1 = np.min(pwage)
    v_ds2 = np.percentile(pwage,25)
    v_ds3 = np.mean(pwage)
    v_ds4 = np.median(pwage)
    v_ds5 = np.percentile(pwage,50)
    v_ds6 = np.percentile(pwage,75)
    v_ds7 = np.max(pwage)
    matrics=[v_ds,v_ds1,v_ds2,v_ds3,v_ds4,v_ds5,v_ds6,v_ds7]
    ID = ['count','min','p_25','mean','median','p_50','p_75','max']
    v_ddf.append(matrics)

# %%
pd.DataFrame(v_ddf,index=num,columns = ID).T
# Out:
#         no_of_employees   yr_of_estab  prevailing_wage
# count       25480.00000  25480.000000     25480.000000
# min           -26.00000   1800.000000         2.136700
# p_25         1022.00000   1976.000000     34015.480000
# mean         5667.04321   1979.409929     74455.814592
# median       2109.00000   1997.000000     70308.210000
# p_50         2109.00000   1997.000000     70308.210000
# p_75         3504.00000   2005.000000    107735.512500
# max        602069.00000   2016.000000    319210.270000

# %%
v_ddf = []
for i in num:
    pwage = ds[i]
    v_ds = pwage.count()
    v_ds1 = np.min(pwage)
    v_ds2 = np.percentile(pwage,25)
    v_ds3 = np.mean(pwage)
    v_ds4 = np.median(pwage)
    v_ds5 = np.percentile(pwage,50)
    v_ds6 = np.percentile(pwage,75)
    v_ds7 = np.max(pwage)
    matrics=[v_ds,v_ds1,v_ds2,v_ds3,v_ds4,v_ds5,v_ds6,v_ds7]
    ID = ['count','min','p_25','mean','median','p_50','p_75','max']
    v_ddf.append(matrics)

pd.DataFrame(v_ddf,index=num,columns = ID).T
# Out:
#         no_of_employees   yr_of_estab  prevailing_wage
# count       25480.00000  25480.000000     25480.000000
# min           -26.00000   1800.000000         2.136700
# p_25         1022.00000   1976.000000     34015.480000
# mean         5667.04321   1979.409929     74455.814592
# median       2109.00000   1997.000000     70308.210000
# p_50         2109.00000   1997.000000     70308.210000
# p_75         3504.00000   2005.000000    107735.512500
# max        602069.00000   2016.000000    319210.270000

# %% [markdown]
# **Percentile**

# %% [markdown]
# - 25% = 34015.480000
#
#     - There is a 25% of total data has values less than wage 34015.48
#
# - Total data = 25480
#
#     - 25% of total data
#
#     - 2548 x 25/100 = 6370
#
#     - There is 6370 employess has wages less than 34015.48

# %%
pwage = ds['prevailing_wage']
P_25 = np.percentile(pwage,25)
con = pwage < P_25
print(len(ds[con]))
len(ds[con]) == 25480 * 25/100
# Out:
# 6370
# True

# %%
pwage = ds['prevailing_wage']
P_50 = np.percentile(pwage,50)
con = pwage < P_50
print(len(ds[con]))
len(ds[con]) == 25480 * 50/100
# Out:
# 12740
# True

# %%
pwage = ds['prevailing_wage']
P_75 = np.percentile(pwage,75)
con = pwage < P_75
print(len(ds[con]))
len(ds[con]) == 25480 * 75/100
# Out:
# 19110
# True

# %% [markdown]
# ### Emperical Rule

# %%
Mean = ds['prevailing_wage'].mean()

# %%
std = ds['prevailing_wage'].std()

# %%
lb = Mean - 1*std
ub = Mean + 1*std

# %%
print(lb)
# Out:
# 21639.872265218262

# %%
print(ub)
# Out:
# 127271.7569189654

# %%
con1 = pwage>lb
con2 = pwage<ub
con = con1 & con2
print(len(ds[con]))
len(ds[con])== 25480*68/100
# Out:
# 17171
# False

# %% [markdown]
# - Emperical rule valid for Normal distribution
#
# - The above analysis conclude, data does not follow normalization

# %% [markdown]
# ### Histogram

# %%
pwage.hist   # it is a skewed data
# Out:
# <Axes: >

# %%
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
wage = ds['prevailing_wage']
plt.hist(wage)
plt.show()

# %% [markdown]
# - for one interval we need two values
#
# - 10 intervals so we need 11 values
#
# - function return 3 outputs
#
#     - count of each interval
#
#     - interval values
#
#     - number of intervals

# %%
wage_data = ds['prevailing_wage']
lb = 2.13670000e+00
ub = 3.19229500e+04
con1 = wage_data >= lb
con2 = wage_data <= ub
con3 = con1 & con2
len(ds[con3])
# Out:
# 6038

# %%
# for one interval we need two values 
# 10 intrvals so we need 11 values 
# function return 3 outputs
      # count of each interval 
      # interval values
      # numbeer of intervals

# %% [markdown]
# - we undrstand the **percentile**
#
# - we explore about **emperical rule**
#
# - then **emperical rule ** failed
#
# - that means the data does not follow **normal distubution**
#
# - we also checked with **histogram plot**
#
# - histogram plot also supported our research : data does not follow **normality**
#
# - it has **right skew** , so that **outliers** present
#
# - we need to visualize outliers using **boxplot**

# %%
plt.boxplot(wage_data,vert=False)
plt.show()

# %%
value = ds['prevailing_wage'].values
value
# Out:
# array([   592.2029,  83425.65  , 122996.86  , ..., 146298.85  ,
#         86154.77  ,  70876.91  ])

# %%
Q1 = np.percentile(value,25)
Q2 = np.percentile(value,50)
Q3 = np.percentile(value,75)
iqr = Q3 - Q1
lb = Q1 - 1.5*iqr
ub = Q3 + 1.5*iqr

con1 = value < lb
con2 = value > ub
con = con1 | con2
outliers_ds = (ds[con])
outliers_ds['prevailing_wage']
outliers_ds['prevailing_wage'].values
l1  = outliers_ds['prevailing_wage'].values.tolist()

# %%
wage_median = ds['prevailing_wage'].median()
wage_data = ds['prevailing_wage']
new_wage = []

# %%
for i in wage_data:
    if i in l1:
        new_wage.append(wage_median)
    else:
        new_wage.append(i)

# %%
new_wage
# Out:
# [592.2029,
#  83425.65,
#  122996.86,
#  83434.03,
#  149907.39,
#  78252.14,
#  53635.39,
#  418.2298,
#  74362.19,
#  67514.76,
#  83588.56,
#  70813.09,
#  28663.05,
#  107196.03,
#  70308.20999999999,
#  74108.02,
#  3706.79,
#  16132.61,
#  150441.13,
#  79948.12,
#  71128.98,
#  137694.98,
#  45642.39,
#  90108.38,
#  71286.04,
#  99489.65,
#  86332.95,
#  103029.33,
#  40925.86,
#  189190.48,
#  79594.12,
#  135866.13,
#  72077.57,
#  81921.18,
#  70308.20999999999,
#  92421.92,
#  2490.12,
#  110817.26,
#  50960.01,
#  125336.9,
#  39633.32,
#  156326.33,
#  43630.58,
#  54614.42,
#  28989.87,
#  22924.91,
#  61567.75,
#  156251.17,
#  86022.02,
#  49565.37,
#  66191.41,
#  95623.2,
#  115014.05,
#  35018.04,
#  230.8072,
#  113799.64,
#  85854.09,
#  14174.04,
#  47176.84,
#  4949.28,
#  67410.59,
#  58791.58,
#  103.2216,
#  62591.57,
#  102919.59,
#  123468.56,
#  82324.64,
#  5319.49,
#  153019.94,
#  38059.89,
#  230.327,
#  61521.92,
#  121316.5,
#  122540.55,
# ...

# %%
# satep - 1 : q1
# step - 2 : q2
# step - 3 : q3
# step - 4 : iqr = q3-q1
# step - 5 : lb = q1-1.5*iqr
# step - 6 : ub = q3+1.5*iqr
# step - 7 : con1 
# step - 8 : con2 
# step - 9 : con
#step - 10 : get this column

# %%
v = ds ['prevailing_wage'].values
v

# %%
q1 = np.percentile(wage_data,25)
q2 = np.percentile(wage_data, 50 )
q3 = np.percentile(wage_data, 75)
iqr = q3 - q1
lb = q1 - 1.5*iqr
ub = q3 + 1.5*iqr
con1 = wage_data<lb
con2 = wage_data>ub
con3 = con1 | con2
len(visa_ds[con3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 10
#       8 con2 = wage_data>ub
#       9 con3 = con1 | con2
# ---> 10 len(visa_ds[con3])
#
# NameError: name 'visa_ds' is not defined

# %%
q1 = np.percentile(wage_data, 25)
q2 = np.percentile(wage_data, 50 )
q3 = np.percentile(wage_data, 75)
iqr = q3 - q1
lb = q1 - 1.5*iqr
ub = q3 + 1.5*iqr
con1 = wage_data<lb
con2 = wage_data>ub
con3 = con1 | con2
len(visa_ds[con3])
outliers_df = visa_df[con3]
outliers_df['prevailing_wage']
outliers_df['prevailing_wage'].values
outliers_list = outliers_df['prevailing_wage'].values.tolist()

# %%
# i want to call the each observation of wage data 
# if that observation will available in this 427 values
# the that observation will replace by median
# otherwise that obervation will be available as it is

wage_median = visa_ds['prevailing_wage'].median()
wage_data = visa_ds['prevailing_wage']
new_wage_data=[]
for i in wage_data:
    if i in outliers_list:
        new_wage_data.append(wage_median)
    else:
        new_wage_data.append(i)

# %% [markdown]
# **winsoriazation**
#
# - whatever the outliers less than lb fill with lb
#
# - whatever the outliers grater than ub fill witn ub
#
# - in numpy we have method clip

# %%
# step-1 : get the wage data values
# step-2 : calculate lb
# step-3 : calculate ub
# step-4 : check the parameters and apply in numpy np.clip()
# step-5 : again implement above visulation analysis


wage_data=visa_df['prevailing_wage']
q1 = np.percentile(wage_data, 25)
q2 = np.percentile(wage_data, 50 )
q3 = np.percentile(wage_data, 75)
